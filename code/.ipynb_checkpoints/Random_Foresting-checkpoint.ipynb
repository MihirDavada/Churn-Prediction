# %%
import pandas as pd
import numpy as np

# %%
df_o = pd.read_csv('churn_clean.csv')
df = df_o.copy()
df
# Out:
#       Unnamed: 0  gender SeniorCitizen Partner Dependents PhoneService  \
# 0              0  Female            No     Yes         No           No
# 1              1    Male            No      No         No          Yes
# 2              2    Male            No      No         No          Yes
# 3              3    Male            No      No         No           No
# 4              4  Female            No      No         No          Yes
# ...          ...     ...           ...     ...        ...          ...
# 7038        7038    Male            No     Yes        Yes          Yes
# 7039        7039  Female            No     Yes        Yes          Yes
# 7040        7040  Female            No     Yes        Yes           No
# 7041        7041    Male           Yes     Yes         No          Yes
# 7042        7042    Male            No      No         No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
df[df['Unnamed: 0'] == 488]
# Out:
#      Unnamed: 0  gender SeniorCitizen Partner Dependents PhoneService  \
# 488         488  Female            No     Yes        Yes           No
#
#         MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 488  No phone service             DSL            Yes           No  ...
#
#     TechSupport StreamingTV StreamingMovies  Contract PaperlessBilling  \
# 488         Yes         Yes              No  Two year              Yes
#
#                  PaymentMethod MonthlyCharges  TotalCharges  Churn  \
# 488  Bank transfer (automatic)          52.55      1397.475      0
#
#      tenure_group
# 488           NaN
#
# [1 rows x 21 columns]

# %%
labels = [i+1 for i in range(20)]

# cutting into bins
df['MonthlyCharges'] = pd.cut(df.MonthlyCharges, range(18, 120, 5), right=False, labels=labels)
df['MonthlyCharges'].value_counts()
# Out:
# 1     1185
# 13     504
# 12     453
# 14     450
# 15     440
# 16     424
# 2      421
# 11     421
# 17     395
# 18     364
# 8      327
# 7      307
# 6      261
# 9      254
# 10     219
# 19     214
# 20     110
# 4      105
# 5       99
# 3       84
# Name: MonthlyCharges, dtype: int64

# %%
df['TotalCharges'].describe()
# min = 18
# max = 8684
# Out:
# count    7043.000000
# mean     2281.916928
# std      2265.270398
# min        18.800000
# 25%       402.225000
# 50%      1397.475000
# 75%      3786.600000
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
labels = [i+1 for i in range(87)]

# cutting into bins
df['TotalCharges'] = pd.cut(df.TotalCharges, range(1,8800, 100), right=False, labels=labels)
df['TotalCharges'].value_counts()
# Out:
# 1     819
# 2     363
# 3     322
# 4     252
# 5     245
#      ...
# 82     14
# 85     13
# 83      8
# 86      5
# 87      3
# Name: TotalCharges, Length: 87, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0  gender SeniorCitizen Partner Dependents PhoneService  \
# 0           0  Female            No     Yes         No           No
# 1           1    Male            No      No         No          Yes
# 2           2    Male            No      No         No          Yes
# 3           3    Male            No      No         No           No
# 4           4  Female            No      No         No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df[df['Unnamed: 0'] == 488]
# Out:
#      Unnamed: 0  gender SeniorCitizen Partner Dependents PhoneService  \
# 488         488  Female            No     Yes        Yes           No
#
#         MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 488  No phone service             DSL            Yes           No  ...
#
#     TechSupport StreamingTV StreamingMovies  Contract PaperlessBilling  \
# 488         Yes         Yes              No  Two year              Yes
#
#                  PaymentMethod MonthlyCharges TotalCharges Churn  tenure_group
# 488  Bank transfer (automatic)              7           14     0           NaN
#
# [1 rows x 21 columns]

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#       gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0     Female            No     Yes         No           No  No phone service
# 1       Male            No      No         No          Yes                No
# 2       Male            No      No         No          Yes                No
# 3       Male            No      No         No           No  No phone service
# 4     Female            No      No         No          Yes                No
# ...      ...           ...     ...        ...          ...               ...
# 7038    Male            No     Yes        Yes          Yes               Yes
# 7039  Female            No     Yes        Yes          Yes               Yes
# 7040  Female            No     Yes        Yes           No  No phone service
# 7041    Male           Yes     Yes         No          Yes               Yes
# 7042    Male            No      No         No          Yes                No
#
# ...

# %%
# upsampling

from sklearn.utils import resample

#create two different dataframe of majority and minority class 
df_majority = df[(df['Churn']==0)] 
df_minority = df[(df['Churn']==1)] 

# upsample minority class
df_minority_upsampled = resample(df_minority, replace=True, n_samples= 5174,random_state=42)

# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_minority_upsampled, df_majority])

# %%
df_upsampled
# Out:
#       gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 4290  Female            No     Yes        Yes           No  No phone service
# 5547  Female            No      No         No          Yes                No
# 3302    Male            No      No         No          Yes               Yes
# 4949    Male            No      No         No           No  No phone service
# 4307  Female           Yes      No         No          Yes               Yes
# ...      ...           ...     ...        ...          ...               ...
# 7037  Female            No      No         No          Yes                No
# 7038    Male            No     Yes        Yes          Yes               Yes
# 7039  Female            No     Yes        Yes          Yes               Yes
# 7040  Female            No     Yes        Yes           No  No phone service
# 7042    Male            No      No         No          Yes                No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   object
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   PhoneService      7043 non-null   object
#  5   MultipleLines     7043 non-null   object
#  6   InternetService   7043 non-null   object
#  7   OnlineSecurity    7043 non-null   object
#  8   OnlineBackup      7043 non-null   object
#  9   DeviceProtection  7043 non-null   object
#  10  TechSupport       7043 non-null   object
#  11  StreamingTV       7043 non-null   object
#  12  StreamingMovies   7043 non-null   object
#  13  Contract          7043 non-null   object
#  14  PaperlessBilling  7043 non-null   object
#  15  PaymentMethod     7043 non-null   object
# ...

# %%
y = df_upsampled['Churn']
y
# Out:
# 4290    1
# 5547    1
# 3302    1
# 4949    1
# 4307    1
#        ..
# 7037    0
# 7038    0
# 7039    0
# 7040    0
# 7042    0
# Name: Churn, Length: 10348, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

#create instance of label encoder
lab = LabelEncoder()

#perform label encoding on 'team' column

df1 = df_upsampled.select_dtypes([np.object]) 
for i,col in enumerate(df1.columns):
    df_upsampled[col] = lab.fit_transform(df_upsampled[col])
# Out:
# C:\Users\158359\AppData\Local\Temp\ipykernel_20852\3347880901.py:8: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df1 = df_upsampled.select_dtypes([np.object])

# %%
df_upsampled
# Out:
#       gender  SeniorCitizen  Partner  Dependents  PhoneService  MultipleLines  \
# 4290       0              0        1           1             0              1
# 5547       0              0        0           0             1              0
# 3302       1              0        0           0             1              2
# 4949       1              0        0           0             0              1
# 4307       0              1        0           0             1              2
# ...      ...            ...      ...         ...           ...            ...
# 7037       0              0        0           0             1              0
# 7038       1              0        1           1             1              2
# 7039       0              0        1           1             1              2
# 7040       0              0        1           1             0              1
# 7042       1              0        0           0             1              0
#
# ...

# %%
df_upsampled.to_csv("beformodel.csv")

# %%
y = df_upsampled['Churn']
df_upsampled.drop(['Churn'],axis = 1 , inplace = True)

# %%
# random forest

from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report



# split
x_train, x_test, y_train, y_test = train_test_split(df_upsampled, y, test_size =0.1)

# fit
classifier= RandomForestClassifier(n_estimators= 90, criterion="gini")  
classifier.fit(x_train, y_train)  

# predict
y_pred_rf= classifier.predict(x_test)

print(metrics.confusion_matrix(y_test , y_pred_rf))
# report
print(classification_report(y_test, y_pred_rf, labels=[0,1]))
# Out:
# [[464  81]
#  [ 25 465]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.85      0.90       545
#            1       0.85      0.95      0.90       490
#
#     accuracy                           0.90      1035
#    macro avg       0.90      0.90      0.90      1035
# weighted avg       0.90      0.90      0.90      1035

# %%
# !pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df_upsampled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10348 entries, 4290 to 7042
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            10348 non-null  int32
#  1   SeniorCitizen     10348 non-null  int32
#  2   Partner           10348 non-null  int32
#  3   Dependents        10348 non-null  int32
#  4   PhoneService      10348 non-null  int32
#  5   MultipleLines     10348 non-null  int32
#  6   InternetService   10348 non-null  int32
#  7   OnlineSecurity    10348 non-null  int32
#  8   OnlineBackup      10348 non-null  int32
#  9   DeviceProtection  10348 non-null  int32
#  10  TechSupport       10348 non-null  int32
#  11  StreamingTV       10348 non-null  int32
#  12  StreamingMovies   10348 non-null  int32
#  13  Contract          10348 non-null  int32
#  14  PaperlessBilling  10348 non-null  int32
#  15  PaymentMethod     10348 non-null  int32
# ...

# %%
df_upsampled['MonthlyCharges'] = pd.to_numeric(df_upsampled['MonthlyCharges'] ,  errors='coerce')
df_upsampled['TotalCharges'] = pd.to_numeric(df_upsampled['TotalCharges'] ,  errors='coerce')

# %%
df_upsampled['MonthlyCharges'].isnull().sum()
# Out:
# 10

# %%
df_upsampled['MonthlyCharges'].fillna(method ='ffill', inplace = True)
df_upsampled['MonthlyCharges'].isnull().sum()
# Out:
# 0

# %%
df_upsampled['MonthlyCharges'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 10348 entries, 4290 to 7042
# Series name: MonthlyCharges
# Non-Null Count  Dtype
# --------------  -----
# 10348 non-null  float64
# dtypes: float64(1)
# memory usage: 161.7 KB

# %%
import xgboost as xgb

# split
x_train, x_test, y_train, y_test = train_test_split(df_upsampled, y, test_size =0.1)


model=xgb.XGBClassifier(random_state=1,learning_rate=0.01)
model.fit(x_train, y_train)
model.score(x_test,y_test)
# Out:
# 0.7758454106280194
